# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# Try to use GPU TSNE (cuML), fallback to CPU TSNE (openTSNE)
try:
    import cupy as cp
    from cuml.manifold import TSNE as cuTSNE
    gpu_available = True
    print("✅ Using GPU cuML TSNE")
except ImportError:
    from openTSNE import TSNE as cpuTSNE
    gpu_available = False
    print("⚠️ cuML not available, falling back to CPU openTSNE")

# Set your directory
tsne_dir = '/c2/jinakim/Drug_Discovery_j/analysis/tsne_last/base_cX_mX_/'

# List all .npz files
files = sorted([f for f in os.listdir(tsne_dir) if f.endswith('.npz')])

# Process each file
for f in files:
    file_path = os.path.join(tsne_dir, f)
    save_name = f"{f.replace('.npz', '')}_tsne_sampled512.png"
    save_path = os.path.join(tsne_dir, save_name)

    # --- Skip if already exists ---
    if os.path.exists(save_path):
        print(f"⏩ {save_name} already exists. Skipping.")
        continue

    print(f"\n🚀 Processing {file_path}")

    # Load the .npz file
    data = np.load(file_path)
    embeddings = data['embeddings']
    labels = data['labels']

    print(f"✅ Loaded embeddings: {embeddings.shape}, labels: {labels.shape}")

    # --- Randomly sample 512 points per label ---
    num_samples_per_class = 512
    sampled_embeddings = []
    sampled_labels = []

    for label_value in np.unique(labels):
        indices = np.where(labels == label_value)[0]
        if len(indices) < num_samples_per_class:
            print(f"⚠️ Warning: label {label_value} has only {len(indices)} samples, using all available.")
            chosen_indices = np.random.choice(indices, len(indices), replace=False)
        else:
            chosen_indices = np.random.choice(indices, num_samples_per_class, replace=False)

        sampled_embeddings.append(embeddings[chosen_indices])
        sampled_labels.append(labels[chosen_indices])

    # Concatenate sampled data
    embeddings = np.concatenate(sampled_embeddings, axis=0)
    labels = np.concatenate(sampled_labels, axis=0)

    print(f"✅ Sampled embeddings: {embeddings.shape}, labels: {labels.shape}")

    # --- Run t-SNE ---
    if gpu_available:
        embeddings_gpu = cp.asarray(embeddings)
        tsne = cuTSNE(n_components=2, random_state=42)
        embeddings_2d_gpu = tsne.fit_transform(embeddings_gpu)
        embeddings_2d = cp.asnumpy(embeddings_2d_gpu)
    else:
        tsne = cpuTSNE(n_components=2, n_jobs=8, random_state=42)
        embeddings_2d = tsne.fit(embeddings)

    # --- Plot ---
    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], c=labels, cmap='tab10', s=5)
    plt.title(f"t-SNE of {f.replace('.npz', '')} (Sampled 512/class)")
    plt.colorbar(scatter, ticks=np.unique(labels), label='Label')
    plt.grid(True)
    plt.tight_layout()

    # Save figure
    plt.savefig(save_path)
    print(f"✅ Saved plot to {save_path}")
    plt.close()

print("\n🏁 All done!")
# Out:
# ⚠️ cuML not available, falling back to CPU openTSNE
#
# 🚀 Processing /c2/jinakim/Drug_Discovery_j/analysis/tsne_last/base_cX_mX_/dsets_dpp4_count.npz
# ✅ Loaded embeddings: (19264, 64), labels: (19264,)
# ✅ Sampled embeddings: (1536, 64), labels: (1536,)
# ✅ Saved plot to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last/base_cX_mX_/dsets_dpp4_count_tsne_sampled512.png
#
# 🚀 Processing /c2/jinakim/Drug_Discovery_j/analysis/tsne_last/base_cX_mX_/dsets_hivprot_bit.npz
# ✅ Loaded embeddings: (19264, 64), labels: (19264,)
# ✅ Sampled embeddings: (1536, 64), labels: (1536,)
# ✅ Saved plot to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last/base_cX_mX_/dsets_hivprot_bit_tsne_sampled512.png
#
# 🚀 Processing /c2/jinakim/Drug_Discovery_j/analysis/tsne_last/base_cX_mX_/dsets_hivprot_count.npz
# ✅ Loaded embeddings: (19264, 64), labels: (19264,)
# ✅ Sampled embeddings: (1536, 64), labels: (1536,)
# ✅ Saved plot to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last/base_cX_mX_/dsets_hivprot_count_tsne_sampled512.png
#
# 🚀 Processing /c2/jinakim/Drug_Discovery_j/analysis/tsne_last/base_cX_mX_/strans_dpp4_count.npz
# ✅ Loaded embeddings: (19264, 64), labels: (19264,)
# ✅ Sampled embeddings: (1536, 64), labels: (1536,)
# ✅ Saved plot to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last/base_cX_mX_/strans_dpp4_count_tsne_sampled512.png
#
# 🚀 Processing /c2/jinakim/Drug_Discovery_j/analysis/tsne_last/base_cX_mX_/strans_hivprot_bit.npz
# ✅ Loaded embeddings: (19264, 32), labels: (19264,)
# ✅ Sampled embeddings: (1536, 32), labels: (1536,)
# ✅ Saved plot to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last/base_cX_mX_/strans_hivprot_bit_tsne_sampled512.png
#
# 🚀 Processing /c2/jinakim/Drug_Discovery_j/analysis/tsne_last/base_cX_mX_/strans_hivprot_count.npz
# ✅ Loaded embeddings: (19264, 64), labels: (19264,)
# ✅ Sampled embeddings: (1536, 64), labels: (1536,)
# ✅ Saved plot to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last/base_cX_mX_/strans_hivprot_count_tsne_sampled512.png
#
# 🏁 All done!

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# Try to use GPU TSNE (cuML), fallback to CPU TSNE (openTSNE)
try:
    import cupy as cp
    from cuml.manifold import TSNE as cuTSNE
    gpu_available = True
    print("✅ Using GPU cuML TSNE")
except ImportError:
    from openTSNE import TSNE as cpuTSNE
    gpu_available = False
    print("⚠️ cuML not available, falling back to CPU openTSNE")

# Set your directory
tsne_dir = '/c2/jinakim/Drug_Discovery_j/analysis/tsne/base_cX_mO_/'

# List all .npz files
files = sorted([f for f in os.listdir(tsne_dir) if f.endswith('.npz')])

# Process each file
for f in files:
    file_path = os.path.join(tsne_dir, f)
    print(f"\n🚀 Processing {file_path}")

    # Load the .npz file
    data = np.load(file_path)
    embeddings = data['embeddings']
    labels = data['labels']

    print(f"✅ Loaded embeddings: {embeddings.shape}, labels: {labels.shape}")

    # --- Randomly sample 512 points per label ---
    num_samples_per_class = 512
    sampled_embeddings = []
    sampled_labels = []

    for label_value in np.unique(labels):
        # if label_value == 0:
        #     continue
        indices = np.where(labels == label_value)[0]
        if len(indices) < num_samples_per_class:
            print(f"⚠️ Warning: label {label_value} has only {len(indices)} samples, using all available.")
            chosen_indices = np.random.choice(indices, len(indices), replace=False)
        else:
            chosen_indices = np.random.choice(indices, num_samples_per_class, replace=False)

        sampled_embeddings.append(embeddings[chosen_indices])
        sampled_labels.append(labels[chosen_indices])

    # Concatenate sampled data
    embeddings = np.concatenate(sampled_embeddings, axis=0)
    labels = np.concatenate(sampled_labels, axis=0)

    print(f"✅ Sampled embeddings: {embeddings.shape}, labels: {labels.shape}")

    # --- Run t-SNE ---
    if gpu_available:
        embeddings_gpu = cp.asarray(embeddings)
        tsne = cuTSNE(n_components=2, random_state=42)
        embeddings_2d_gpu = tsne.fit_transform(embeddings_gpu)
        embeddings_2d = cp.asnumpy(embeddings_2d_gpu)
    else:
        tsne = cpuTSNE(n_components=2, n_jobs=8, random_state=42)
        embeddings_2d = tsne.fit(embeddings)

    # --- Plot ---
    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], c=labels, cmap='tab10', s=5)
    plt.title(f"t-SNE of {f.replace('.npz', '')} (Sampled 512/class)")
    plt.colorbar(scatter, ticks=np.unique(labels), label='Label')
    plt.grid(True)
    plt.tight_layout()

    # Save figure
    save_name = f"{f.replace('.npz', '')}_tsne_sampled512.png"
    save_path = os.path.join(tsne_dir, save_name)
    plt.savefig(save_path)
    print(f"✅ Saved plot to {save_path}")
    plt.close()
# Out:
# ⚠️ cuML not available, falling back to CPU openTSNE
#
# 🚀 Processing /c2/jinakim/Drug_Discovery_j/analysis/tsne/base_cX_mO_/dsets_dpp4_bit.npz
# ✅ Loaded embeddings: (25472, 512), labels: (25472,)
# ⚠️ Warning: label 2 has only 64 samples, using all available.
# ✅ Sampled embeddings: (1600, 512), labels: (1600,)
# ✅ Saved plot to /c2/jinakim/Drug_Discovery_j/analysis/tsne/base_cX_mO_/dsets_dpp4_bit_tsne_sampled512_2.png
#
# 🚀 Processing /c2/jinakim/Drug_Discovery_j/analysis/tsne/base_cX_mO_/dsets_dpp4_count.npz
# ✅ Loaded embeddings: (25472, 512), labels: (25472,)
# ⚠️ Warning: label 2 has only 64 samples, using all available.
# ✅ Sampled embeddings: (1600, 512), labels: (1600,)
# ✅ Saved plot to /c2/jinakim/Drug_Discovery_j/analysis/tsne/base_cX_mO_/dsets_dpp4_count_tsne_sampled512_2.png
#
# 🚀 Processing /c2/jinakim/Drug_Discovery_j/analysis/tsne/base_cX_mO_/dsets_hivprot_bit.npz
# ✅ Loaded embeddings: (22528, 512), labels: (22528,)
# ⚠️ Warning: label 2 has only 64 samples, using all available.
# ✅ Sampled embeddings: (1600, 512), labels: (1600,)
# ✅ Saved plot to /c2/jinakim/Drug_Discovery_j/analysis/tsne/base_cX_mO_/dsets_hivprot_bit_tsne_sampled512_2.png
#
# 🚀 Processing /c2/jinakim/Drug_Discovery_j/analysis/tsne/base_cX_mO_/dsets_hivprot_count.npz
# ✅ Loaded embeddings: (22528, 512), labels: (22528,)
# ⚠️ Warning: label 2 has only 64 samples, using all available.
# ✅ Sampled embeddings: (1600, 512), labels: (1600,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 66
#      64 else:
#      65     tsne = cpuTSNE(n_components=2, n_jobs=8, random_state=42)
# ---> 66     embeddings_2d = tsne.fit(embeddings)
#      68 # --- Plot ---
#      69 plt.figure(figsize=(8, 6))
#
# File /c2/jinakim/miniconda3/envs/drug/lib/python3.9/site-packages/openTSNE/tsne.py:1252, in TSNE.fit(self, X, affinities, initialization)
#    1247 embedding = self.prepare_initial(X, affinities, initialization)
#    1249 try:
#    1250     # Early exaggeration with lower momentum to allow points to find more
#    1251     # easily move around and find their neighbors
# -> 1252     embedding.optimize(
#    1253         n_iter=self.early_exaggeration_iter,
#    1254         exaggeration=self.early_exaggeration,
#    1255         momentum=self.initial_momentum,
#    1256         inplace=True,
#    1257         propagate_exception=True,
#    1258     )
#    1260     # Restore actual affinity probabilities and increase momentum to get
#    1261     # final, optimized embedding
#    1262     embedding.optimize(
#    1263         n_iter=self.n_iter,
#    1264         exaggeration=self.exaggeration,
#    (...)
#    1267         propagate_exception=True,
#    1268     )
#
# File /c2/jinakim/miniconda3/envs/drug/lib/python3.9/site-packages/openTSNE/tsne.py:679, in TSNEEmbedding.optimize(self, n_iter, inplace, propagate_exception, **gradient_descent_params)
#     674 _handle_nice_params(embedding, optim_params)
#     676 try:
#     677     # Run gradient descent with the embedding optimizer so gains are
#     678     # properly updated and kept
# --> 679     error, embedding = embedding.optimizer(
#     680         embedding=embedding, P=self.affinities.P, **optim_params
#     681     )
#     683 except OptimizationInterrupt as ex:
#     684     log.info("Optimization was interrupted with callback.")
#
# File /c2/jinakim/miniconda3/envs/drug/lib/python3.9/site-packages/openTSNE/tsne.py:1790, in gradient_descent.__call__(self, embedding, P, n_iter, objective_function, learning_rate, momentum, exaggeration, dof, min_gain, max_grad_norm, max_step_norm, theta, n_interpolation_points, min_num_intervals, ints_in_interval, reference_embedding, n_jobs, use_callbacks, callbacks, callbacks_every_iters, verbose)
#    1786 # Evaluate error on 50 iterations for logging, or when callbacks
#    1787 should_eval_error = should_call_callback or \
#    1788     (verbose and (iteration + 1) % 50 == 0)
# -> 1790 error, gradient = objective_function(
#    1791     embedding,
#    1792     P,
#    1793     dof=dof,
#    1794     bh_params=bh_params,
#    1795     fft_params=fft_params,
#    1796     reference_embedding=reference_embedding,
#    1797     n_jobs=n_jobs,
#    1798     should_eval_error=should_eval_error,
#    1799 )
#    1801 # Clip gradients to avoid points shooting off. This can be an issue
#    1802 # when applying transform and points are initialized so that the new
#    1803 # points overlap with the reference points, leading to large
#    1804 # gradients
#    1805 if max_grad_norm is not None:
#
# File /c2/jinakim/miniconda3/envs/drug/lib/python3.9/site-packages/openTSNE/tsne.py:1470, in kl_divergence_bh(embedding, P, dof, bh_params, reference_embedding, should_eval_error, n_jobs, **_)
#    1468 # Compute negative gradient
#    1469 tree = QuadTree(reference_embedding)
# -> 1470 sum_Q = _tsne.estimate_negative_gradient_bh(
#    1471     tree,
#    1472     embedding,
#    1473     gradient,
#    1474     **bh_params,
#    1475     dof=dof,
#    1476     num_threads=n_jobs,
#    1477     pairwise_normalization=pairwise_normalization,
#    1478 )
#    1479 del tree
#    1481 # Compute positive gradient
#
# KeyboardInterrupt:

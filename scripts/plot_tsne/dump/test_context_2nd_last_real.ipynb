# %%
import torch.nn.functional as F
import torch
from main_merck_all_real import get_dataset
from utils import set_seed, get_optimizer, InfIterator
from arguments import get_arguments
from main_origin import get_model
from setenc import get_mixer

import os
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
def calc_loss(y_hat, y, test=False):
    return F.mse_loss(y.cuda().squeeze(), y_hat.cuda().squeeze())

def test(args, dataloader, contextloader=None, model=None, mixer_phi=None, embed_type=None, n_t=10, n_c=5):
    model.eval()
    mixer_phi.eval()
    embedding_list = []
    label_list= []
    loss_list = []
    # print('model ', model)
    # print('mixer_phi ', mixer_phi)
    if embed_type == "train_none":
        with torch.no_grad():
            losses = []
            counts = 0
            for i, (x, y) in enumerate(dataloader):
                if i == n_t:
                    break
                
                if i == 0:
                    torch.save(x, 't_x.pt')
                    torch.save(y, 't_y.pt')
                #     return
                

                y_hat, embedding_list, label_list = model(x=x.to(args.device), context=None, mixer_phi=mixer_phi, embedding_list=embedding_list, label_list=label_list, embed_type=embed_type, embed_test=args.embed_test)

                y = y.cuda().squeeze()
                y_hat = y_hat.cuda().squeeze()

                # y_hat = y_hat[:, 0]
                # print(f"in test: {y.size()=} {y_hat.size()=}")

                loss = calc_loss(y_hat, y, test=True)
                loss_scalar = loss.detach().item()
                loss_list.append(torch.full((x.shape[0],), loss_scalar))

                # print('loss_scalar ', loss_scalar)
                # print('x ', x.size(0))
                # print('y_hat ', y_hat)
                # print('embedding_list ', embedding_list)
                losses.append(loss_scalar * x.size(0))
                counts += x.size(0)
                # if i == 0:
                #     torch.save(x, 'tn_x.pt')
                #     torch.save(y, 'tn_y.pt')
        # self.model.eval()
    elif embed_type == "ood1_none" or embed_type == "ood2_none":
        with torch.no_grad():
            losses = []
            counts = 0
            for i, (x, y) in enumerate(dataloader):
                if i == n_t:
                    break
                
                # if i == 0:
                #     torch.save(x, 't_x.pt')
                #     torch.save(y, 't_y.pt')
                #     return
                

                y_hat, embedding_list, label_list = model(x=x.to(args.device), context=None, mixer_phi=mixer_phi, embedding_list=embedding_list, label_list=label_list, embed_type=embed_type, embed_test=args.embed_test)

                y = y.cuda().squeeze()
                y_hat = y_hat.cuda().squeeze()

                # y_hat = y_hat[:, 0]
                # print(f"in test: {y.size()=} {y_hat.size()=}")

                loss = calc_loss(y_hat, y, test=True)
                loss_scalar = loss.detach().item()
                loss_list.append(torch.full((x.shape[0],), loss_scalar))

                # print('loss_scalar ', loss_scalar)
                # print('x ', x.size(0))
                # print('y_hat ', y_hat)
                # print('embedding_list ', embedding_list)
                losses.append(loss_scalar * x.size(0))
                counts += x.size(0)
                # if i == 0:
                #     torch.save(x, 'tn_x.pt')
                #     torch.save(y, 'tn_y.pt')
        # self.model.eval()
    elif embed_type == "train_context":
        with torch.no_grad():
            losses = []
            counts = 0
            for i, (x, y) in enumerate(dataloader):
                if i == n_t:
                    break
                
                context_samples = []
                
                if i == 0:
                    torch.save(x, 'tc_x.pt')
                    torch.save(y, 'tc_y.pt')

                for i_c, (x_c, y_c) in enumerate(contextloader):
                    if i_c == n_c:
                        break
                    x_c = x_c.reshape(args.batch_size, -1, x_c.size(-1))
                    if args.n_context > 1:
                        n = torch.randint(1, x_c.size(1), size=(1,)).item()
                        x_c = x_c[:, :n]
                        
                    if i == 0 and i_c == 0:
                        torch.save(x_c, 'tc_x_c.pt')
                        torch.save(y_c, 'tc_y_c.pt')
                        
                        
                    # print('$$$$$$')
                    # print('x_c ', x_c.shape)
                    # print('x ', x.shape)
                    
                    # return
                    # context_samples.append(x_c)
                
                # context_samples = torch.cat(context_samples, dim=0).to(args.device)
                # context_samples = context_samples.reshape(args.batch_size, -1, x_c.size(-1))
                
                # print('### context_samples ', context_samples)
                # torch.save(context_samples, f'context_samples_{i}.pth')
                    y_hat, embedding_list, label_list = model(x=x.to(args.device), context=x_c.to(args.device), mixer_phi=mixer_phi, embedding_list=embedding_list, label_list=label_list, embed_type=embed_type, embed_test=args.embed_test)

                    y = y.cuda().squeeze()
                    y_hat = y_hat.cuda().squeeze()

                    # y_hat = y_hat[:, 0]
                    # print(f"in test: {y.size()=} {y_hat.size()=}")

                    loss = calc_loss(y_hat, y, test=True)
                    loss_list.append(torch.full((x.shape[0],), loss.detach().item()))

                    losses.append(loss.item() * x.size(0))
                    counts += x.size(0)
    elif embed_type == "context_none":
        with torch.no_grad():
            losses = []
            counts = 0
            for i, (x, y) in enumerate(dataloader):
                if i == n_t:
                    break
                
                context_samples = []
                
                if i == 0:
                    torch.save(x, 'c_x.pt')
                    torch.save(y, 'c_y.pt')

                for i_c, (x_c, y_c) in enumerate(contextloader):
                    if i_c == n_c:
                        break
                    x_c = x_c.reshape(args.batch_size, -1, x_c.size(-1))
                    if args.n_context > 1:
                        n = torch.randint(1, x_c.size(1), size=(1,)).item()
                        x_c = x_c[:, :n]
                    
                    if i == 0 and i_c == 0:
                        torch.save(x_c, 'c_x_c.pt')
                        torch.save(y_c, 'c_y_c.pt')
                    # print('====')
                    # print('x_c ', x_c.shape)
                    # print('x ', x.shape)
                    
                    # return
                    
                    # context_samples.append(x_c)
                    
                    # B, S, H = x_c.size() <- did this in model
                    # x_c = x_c.view(B*S, H)
                
                # context_samples = torch.cat(context_samples, dim=0).to(args.device)
                # context_samples = context_samples.reshape(args.batch_size, -1, x_c.size(-1))
                
                # print('### context_samples ', context_samples)
                # torch.save(context_samples, f'context_samples_{i}.pth')
                    y_hat, embedding_list, label_list = model(x=x_c.to(args.device), context=x_c.to(args.device), mixer_phi=mixer_phi, embedding_list=embedding_list, label_list=label_list, embed_type=embed_type, embed_test=args.embed_test)

                    y = y.cuda().squeeze()
                    y_hat = y_hat.cuda().squeeze()

                    # y_hat = y_hat[:, 0]
                    # print(f"in test: {y.size()=} {y_hat.size()=}")

                    loss = calc_loss(y_hat, y, test=True)
                    loss_list.append(torch.full((x.shape[0],), loss.detach().item()))

                    losses.append(loss.item() * x.size(0))
                    counts += x.size(0)
    mse = sum(losses) / counts
    return mse, embedding_list, label_list, loss_list

# %%
def save_one_datapoint_features(args, model, mixer_phi, embed_type, n_t, n_c):
    path = f"/c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/{args.embed_test}_"
    os.makedirs(path, exist_ok=True)
    
    f_path = f'/c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/{args.embed_test}_/{args.sencoder}_{args.dataset}_{args.vec_type}_{n_t}_{n_c}_{embed_type}.npz'
    
    
    if os.path.exists(f_path):
        print(f"⏩ {f_path} already exists. Skipping...") 
        return
    
    set_seed(0)
    args.batch_size = 1
    args.tsne_plot = True # because of get_dataset
    args.embed_test = '2nd_last_ours_best'
    all_candidates = ['hivprot', 'dpp4', 'nk1']
    args.specify_ood_dataset = [d for d in all_candidates if d != args.dataset]
    trainloader_test, _, mvalidloader_test, _, contextloader_test, ood1_trainloader_test, ood2_trainloader_test = get_dataset(args=args, test=True)
    
    if "ood" not in embed_type:
        mse, embedding_list, label_list, loss_list = test(args=args, dataloader=trainloader_test, contextloader=contextloader_test, model=model, mixer_phi=mixer_phi, embed_type=embed_type, n_t=n_t, n_c=n_c)
    elif 'ood1' in embed_type:
        mse, embedding_list, label_list, loss_list = test(args=args, dataloader=ood1_trainloader_test, contextloader=contextloader_test, model=model, mixer_phi=mixer_phi, embed_type=embed_type, n_t=n_t, n_c=n_c)
    elif 'ood2' in embed_type:
        mse, embedding_list, label_list, loss_list = test(args=args, dataloader=ood2_trainloader_test, contextloader=contextloader_test, model=model, mixer_phi=mixer_phi, embed_type=embed_type, n_t=n_t, n_c=n_c)
    else:
        raise Exception()
    
    all_embeddings = torch.cat(embedding_list, dim=0)
    all_labels = np.concatenate(label_list, axis=0)
    all_losses = torch.cat(loss_list, dim=0)

    all_labels = torch.tensor(all_labels)
    all_losses = torch.tensor(all_losses)
                
    all_embeddings_np = all_embeddings.numpy()
    all_labels_np = all_labels.numpy()
    all_losses_np = all_losses.numpy()
    
    
    np.savez(f_path, embeddings=all_embeddings_np, labels=all_labels_np, losses=all_losses_np)
    print(f'>>> saved {f_path}')
    
    if 'ood1' in embed_type:
        ood1_trainloader_test._iterator._shutdown_workers()
    elif 'ood2' in embed_type:
        ood2_trainloader_test._iterator._shutdown_workers()
    else:
        trainloader_test._iterator._shutdown_workers()
        if 'context' in embed_type:
            contextloader_test._iterator._shutdown_workers()

# %%
def save_features(data):

    model = data['model']
    mixer_phi = data['mixer_phi']
    optimizer = data['optimizer']
    mixer_optimizer = data['mixer_optimizer']
    
    ltmse, lvmse, vmse, tmse = data['ltmse'], data['lvmse'], data['vmse'], data['tmse ']
    
    print('>> ltmse ', ltmse)
    print('>> tmse ', tmse)
    print('>> lvmse ', lvmse)
    print('>> vmse ', vmse)
    
    args_ = data['args']

    args = get_arguments()

    for k, v in args_.items():
        setattr(args, k, v)

    set_seed(0)

    model = get_model(args=args)
    mixer_phi = get_mixer(args=args)
    # optimizer = get_optimizer(optimizer=args.optimizer, model=model, lr=args.lr, wd=args.wd)
    # optimizermixer = None if mixer_phi is None else get_optimizer(optimizer=args.optimizer, model=mixer_phi, lr=args.clr, wd=args.cwd)

    model.load_state_dict(data['model'])
    mixer_phi.load_state_dict(data['mixer_phi'])
    # optimizer.load_state_dict(data['optimizer'])
    # mixer_optimizer.load_state_dict(data['mixer_optimizer'])

    model = model.to(args.device)
    mixer_phi = mixer_phi.to(args.device)
    
    # for (n_t, n_c) in [(5, 10), (5, 100), (10, 5), (10, 100), (100, 5), (100, 10)]:
    for (n_t, n_c) in [(5, 10), (5, 50), (5, 100), (10, 5), (10, 40), (10, 100), (40, 5), (40, 10), (100, 5),]:
        save_one_datapoint_features(args, model, mixer_phi, "train_none", n_t, n_c)
        save_one_datapoint_features(args, model, mixer_phi, "context_none", n_t, n_c)
        save_one_datapoint_features(args, model, mixer_phi, "train_context", n_t, n_c)
        save_one_datapoint_features(args, model, mixer_phi, "ood1_none", 100, n_c)
        save_one_datapoint_features(args, model, mixer_phi, "ood2_none", 100, n_c)

# %%
import os
import torch

# Directory containing .pth files
tsne_model_dir = '/c2/jinakim/Drug_Discovery_j/tsne_model/tsne_model2/ours_best/'
os.makedirs(tsne_model_dir, exist_ok=True)
# List all .pth files
pth_files = sorted([f for f in os.listdir(tsne_model_dir) if f.endswith('.pth')])

# Load each file
for i, f in enumerate(pth_files):
    # if i > 2:
    #     break
    file_path = os.path.join(tsne_model_dir, f)
    print(f"🚀 Loading {file_path}")
    
    data = torch.load(file_path)
    save_features(data)
    # Now 'data' contains the loaded model or state dict or whatever was saved
    # You can process it here if needed
    # For example, just printing some keys if it's a checkpoint
    # if isinstance(data, dict):
    #     print(f"✅ Loaded {f}: keys = {list(data.keys())}")
    # else:
    #     print(f"✅ Loaded {f}: type = {type(data)}")

print("\n🏁 All models loaded.")
# Out:
# 🚀 Loading /c2/jinakim/Drug_Discovery_j/tsne_model/tsne_model2/ours_best/Model_dsets_dpp4_bit_['tdi', 'metab'].pth
# >> ltmse  0.9483075507112704
# >> tmse  0.9568182459670349
# >> lvmse  0.5266250636842515
# >> vmse  0.5188705093330808
# loading deepsets
# DSEncoder(
#   (encoder): Sequential(
#     (0): PermEquiMax(
#       (Gamma): Linear(in_features=512, out_features=512, bias=True)
#       (Lambda): Linear(in_features=512, out_features=512, bias=False)
#     )
#   )
# )
# Inner args.dataset='dpp4' args.vec_type='bit'
# /tmp/ipykernel_5907/3898882159.py:34: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   all_losses = torch.tensor(all_losses)
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/ours_best_/dsets_dpp4_bit_5_10_train_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_5_10_context_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_5_10_train_context.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_10_ood1_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_10_ood2_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_5_50_train_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_5_50_context_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_5_50_train_context.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_50_ood1_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_50_ood2_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_5_100_train_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_5_100_context_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_5_100_train_context.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_100_ood1_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_100_ood2_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_10_5_train_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_10_5_context_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_10_5_train_context.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_5_ood1_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_5_ood2_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_10_40_train_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_10_40_context_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_10_40_train_context.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_40_ood1_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_40_ood2_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_10_100_train_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_10_100_context_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_10_100_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_100_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_100_ood2_none.npz already exists. Skipping...
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_40_5_train_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_40_5_context_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_40_5_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_5_ood2_none.npz already exists. Skipping...
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_40_10_train_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_40_10_context_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_40_10_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_10_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_10_ood2_none.npz already exists. Skipping...
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_5_train_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_5_context_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_5_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_5_ood2_none.npz already exists. Skipping...
# 🚀 Loading /c2/jinakim/Drug_Discovery_j/tsne_model/tsne_model2/ours_best/Model_dsets_dpp4_count_['tdi', 'thrombin'].pth
# >> ltmse  0.9477982303041118
# >> tmse  1.0625762456786663
# >> lvmse  0.8797251515918307
# >> vmse  0.6107981138759189
# loading deepsets
# DSEncoder(
#   (encoder): Sequential(
#     (0): PermEquiMax(
#       (Gamma): Linear(in_features=512, out_features=512, bias=True)
#       (Lambda): Linear(in_features=512, out_features=512, bias=False)
#     )
#   )
# )
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/ours_best_/dsets_dpp4_count_5_10_train_none.npz already exists. Skipping...
# Inner args.dataset='dpp4' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/ours_best_/dsets_dpp4_count_5_10_context_none.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_5_10_train_context.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_10_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_10_ood2_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_5_50_train_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_5_50_context_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_5_50_train_context.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_50_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_50_ood2_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_5_100_train_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_5_100_context_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_5_100_train_context.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_100_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_100_ood2_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_10_5_train_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_10_5_context_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_10_5_train_context.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_5_ood2_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_10_40_train_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_10_40_context_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_10_40_train_context.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_40_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_40_ood2_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_10_100_train_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_10_100_context_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_10_100_train_context.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_100_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_100_ood2_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_40_5_train_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_40_5_context_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_40_5_train_context.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_5_ood2_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_40_10_train_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_40_10_context_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_40_10_train_context.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_10_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_10_ood2_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_5_train_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_5_context_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_5_train_context.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_5_ood2_none.npz already exists. Skipping...
# 🚀 Loading /c2/jinakim/Drug_Discovery_j/tsne_model/tsne_model2/ours_best/Model_dsets_hivprot_bit_['cb1', 'thrombin'].pth
# >> ltmse  0.6447012108653339
# >> tmse  0.37318192667035915
# >> lvmse  2.535548543930054
# >> vmse  0.596048241853714
# loading deepsets
# DSEncoder(
#   (encoder): Sequential(
#     (0): PermEquiMax(
#       (Gamma): Linear(in_features=512, out_features=512, bias=True)
#       (Lambda): Linear(in_features=512, out_features=512, bias=False)
#     )
#   )
# )
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/ours_best_/dsets_hivprot_bit_5_10_train_none.npz already exists. Skipping...
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/ours_best_/dsets_hivprot_bit_5_10_context_none.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_5_10_train_context.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_10_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_10_ood2_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_5_50_train_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_5_50_context_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_5_50_train_context.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_50_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_50_ood2_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_5_100_train_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_5_100_context_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_5_100_train_context.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_100_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_100_ood2_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_10_5_train_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_10_5_context_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_10_5_train_context.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_5_ood2_none.npz already exists. Skipping...
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_10_40_train_none.npz
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_10_40_context_none.npz
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_10_40_train_context.npz
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_40_ood1_none.npz
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_40_ood2_none.npz
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_10_100_train_none.npz
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_10_100_context_none.npz
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_10_100_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_100_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_100_ood2_none.npz already exists. Skipping...
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_40_5_train_none.npz
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_40_5_context_none.npz
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_40_5_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_5_ood2_none.npz already exists. Skipping...
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_40_10_train_none.npz
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_40_10_context_none.npz
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_40_10_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_10_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_10_ood2_none.npz already exists. Skipping...
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_5_train_none.npz
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_5_context_none.npz
# Inner args.dataset='hivprot' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_5_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_5_ood2_none.npz already exists. Skipping...
# 🚀 Loading /c2/jinakim/Drug_Discovery_j/tsne_model/tsne_model2/ours_best/Model_dsets_hivprot_count_['3a4', 'metab'].pth
# >> ltmse  0.45290947093892453
# >> tmse  0.6648922713834848
# >> lvmse  1.9036614894866943
# >> vmse  0.49322420358657837
# loading deepsets
# DSEncoder(
#   (encoder): Sequential(
#     (0): PermEquiMax(
#       (Gamma): Linear(in_features=512, out_features=512, bias=True)
#       (Lambda): Linear(in_features=512, out_features=512, bias=False)
#     )
#   )
# )
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/ours_best_/dsets_hivprot_count_5_10_train_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_5_10_context_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_5_10_train_context.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_10_ood1_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_10_ood2_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_5_50_train_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_5_50_context_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_5_50_train_context.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_50_ood1_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_50_ood2_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_5_100_train_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_5_100_context_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_5_100_train_context.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_100_ood1_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_100_ood2_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_10_5_train_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_10_5_context_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_10_5_train_context.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_5_ood1_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_5_ood2_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_10_40_train_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_10_40_context_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_10_40_train_context.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_40_ood1_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_40_ood2_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_10_100_train_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_10_100_context_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_10_100_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_100_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_100_ood2_none.npz already exists. Skipping...
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_40_5_train_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_40_5_context_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_40_5_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_5_ood2_none.npz already exists. Skipping...
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_40_10_train_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_40_10_context_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_40_10_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_10_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_10_ood2_none.npz already exists. Skipping...
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_5_train_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_5_context_none.npz
# Inner args.dataset='hivprot' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_5_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_5_ood2_none.npz already exists. Skipping...
# 🚀 Loading /c2/jinakim/Drug_Discovery_j/tsne_model/tsne_model2/ours_best/Model_dsets_nk1_bit_['hivint', 'tdi'].pth
# >> ltmse  0.34256385536208145
# >> tmse  0.386679117665298
# >> lvmse  0.40283313890298206
# >> vmse  0.33185709615548453
# loading deepsets
# DSEncoder(
#   (encoder): Sequential(
#     (0): PermEquiMax(
#       (Gamma): Linear(in_features=512, out_features=512, bias=True)
#       (Lambda): Linear(in_features=512, out_features=512, bias=False)
#     )
#   )
# )
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/ours_best_/dsets_nk1_bit_5_10_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_5_10_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_5_10_train_context.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_10_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_10_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_5_50_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_5_50_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_5_50_train_context.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_50_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_50_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_5_100_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_5_100_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_5_100_train_context.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_100_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_100_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_10_5_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_10_5_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_10_5_train_context.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_5_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_5_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_10_40_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_10_40_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_10_40_train_context.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_40_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_40_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_10_100_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_10_100_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_10_100_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_100_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_100_ood2_none.npz already exists. Skipping...
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_40_5_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_40_5_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_40_5_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_5_ood2_none.npz already exists. Skipping...
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_40_10_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_40_10_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_40_10_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_10_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_10_ood2_none.npz already exists. Skipping...
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_5_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_5_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_5_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_5_ood2_none.npz already exists. Skipping...
# 🚀 Loading /c2/jinakim/Drug_Discovery_j/tsne_model/tsne_model2/ours_best/Model_dsets_nk1_count_['cb1', 'ox2'].pth
# >> ltmse  0.5002809923494059
# >> tmse  0.47298587414099535
# >> lvmse  1.5648151874542235
# >> vmse  0.6295911769072214
# loading deepsets
# DSEncoder(
#   (encoder): Sequential(
#     (0): PermEquiMax(
#       (Gamma): Linear(in_features=512, out_features=512, bias=True)
#       (Lambda): Linear(in_features=512, out_features=512, bias=False)
#     )
#   )
# )
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/ours_best_/dsets_nk1_count_5_10_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_5_10_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_5_10_train_context.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_10_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_10_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_5_50_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_5_50_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_5_50_train_context.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_50_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_50_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_5_100_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_5_100_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_5_100_train_context.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_100_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_100_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_10_5_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_10_5_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_10_5_train_context.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_5_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_5_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_10_40_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_10_40_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_10_40_train_context.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_40_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_40_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_10_100_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_10_100_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_10_100_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_100_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_100_ood2_none.npz already exists. Skipping...
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_40_5_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_40_5_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_40_5_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_5_ood2_none.npz already exists. Skipping...
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_40_10_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_40_10_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_40_10_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_10_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_10_ood2_none.npz already exists. Skipping...
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_5_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_5_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_5_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_5_ood2_none.npz already exists. Skipping...
# 🚀 Loading /c2/jinakim/Drug_Discovery_j/tsne_model/tsne_model2/ours_best/Model_strans_dpp4_bit_['ox1', 'rat_f'].pth
# >> ltmse  0.9666999083859413
# >> tmse  1.116126726542242
# >> lvmse  1.4903597566816542
# >> vmse  0.7559357285499573
# loading set transformer layer='sum'
# STEncoder(
#   (encoder): Sequential(
#     (0): SAB(
#       (mab): MAB(
#         (fc_q): Linear(in_features=512, out_features=512, bias=True)
#         (fc_k): Linear(in_features=512, out_features=512, bias=True)
#         (fc_v): Linear(in_features=512, out_features=512, bias=True)
#         (fc_o): Linear(in_features=512, out_features=512, bias=True)
#       )
#     )
#   )
#   (proj): Linear(in_features=512, out_features=512, bias=True)
# )
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/ours_best_/strans_dpp4_bit_5_10_train_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_5_10_context_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_5_10_train_context.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_100_10_ood1_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_100_10_ood2_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_5_50_train_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_5_50_context_none.npz
# Inner args.dataset='dpp4' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_5_50_train_context.npz
# ...
# >> ltmse  0.3519483157094272
# >> tmse  0.4532926899561103
# >> lvmse  0.7936500509579977
# >> vmse  0.44553430477778116
# loading set transformer layer='sum'
# STEncoder(
#   (encoder): Sequential(
#     (0): SAB(
#       (mab): MAB(
#         (fc_q): Linear(in_features=512, out_features=512, bias=True)
#         (fc_k): Linear(in_features=512, out_features=512, bias=True)
#         (fc_v): Linear(in_features=512, out_features=512, bias=True)
#         (fc_o): Linear(in_features=512, out_features=512, bias=True)
#       )
#     )
#   )
#   (proj): Linear(in_features=512, out_features=512, bias=True)
# )
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/ours_best_/strans_nk1_bit_5_10_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_5_10_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_5_10_train_context.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_10_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_10_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_5_50_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_5_50_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_5_50_train_context.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_50_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_50_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_5_100_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_5_100_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_5_100_train_context.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_100_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_100_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_10_5_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_10_5_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_10_5_train_context.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_5_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_5_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_10_40_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_10_40_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_10_40_train_context.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_40_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_40_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_10_100_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_10_100_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_10_100_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_100_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_100_ood2_none.npz already exists. Skipping...
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_40_5_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_40_5_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_40_5_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_5_ood2_none.npz already exists. Skipping...
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_40_10_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_40_10_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_40_10_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_10_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_10_ood2_none.npz already exists. Skipping...
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_5_train_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_5_context_none.npz
# Inner args.dataset='nk1' args.vec_type='bit'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_5_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_5_ood2_none.npz already exists. Skipping...
# 🚀 Loading /c2/jinakim/Drug_Discovery_j/tsne_model/tsne_model2/ours_best/Model_strans_nk1_count_['cb1', 'logd'].pth
# >> ltmse  0.5088564718323669
# >> tmse  0.5255077862846798
# >> lvmse  0.5956463754177094
# >> vmse  0.5661567191282908
# loading set transformer layer='sum'
# STEncoder(
#   (encoder): Sequential(
#     (0): SAB(
#       (mab): MAB(
#         (fc_q): Linear(in_features=512, out_features=512, bias=True)
#         (fc_k): Linear(in_features=512, out_features=512, bias=True)
#         (fc_v): Linear(in_features=512, out_features=512, bias=True)
#         (fc_o): Linear(in_features=512, out_features=512, bias=True)
#       )
#     )
#   )
#   (proj): Linear(in_features=512, out_features=512, bias=True)
# )
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/ours_best_/strans_nk1_count_5_10_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_5_10_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_5_10_train_context.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_10_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_10_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_5_50_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_5_50_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_5_50_train_context.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_50_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_50_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_5_100_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_5_100_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_5_100_train_context.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_100_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_100_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_10_5_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_10_5_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_10_5_train_context.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_5_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_5_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_10_40_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_10_40_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_10_40_train_context.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_40_ood1_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_40_ood2_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_10_100_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_10_100_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_10_100_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_100_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_100_ood2_none.npz already exists. Skipping...
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_40_5_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_40_5_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_40_5_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_5_ood2_none.npz already exists. Skipping...
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_40_10_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_40_10_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_40_10_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_10_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_10_ood2_none.npz already exists. Skipping...
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_5_train_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_5_context_none.npz
# Inner args.dataset='nk1' args.vec_type='count'
# >>> saved /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_5_train_context.npz
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_5_ood1_none.npz already exists. Skipping...
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_5_ood2_none.npz already exists. Skipping...
#
# 🏁 All models loaded.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

# Try to use GPU TSNE (cuML), fallback to CPU TSNE (openTSNE)
# try:
#     import cupy as cp
#     from cuml.manifold import TSNE as cuTSNE
#     gpu_available = True
#     print("✅ Using GPU cuML TSNE")
# except ImportError:
from openTSNE import TSNE as cpuTSNE
gpu_available = False
print("⚠️ cuML not available, falling back to CPU openTSNE")

# Set your directory
tsne_dir = '/c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/'

# List all .npz files
files = sorted([f for f in os.listdir(tsne_dir) if f.endswith('.npz')])

# --- Group files by their starting prefix (before 3rd underscore) ---
groups = defaultdict(list)
for f in files:
    parts = f.split('_')
    prefix = '_'.join(parts[:5])  # e.g., dsets_dpp4_count
    groups[prefix].append(f)

# --- Process each group ---
for prefix, group_files in groups.items():
    save_path = os.path.join(tsne_dir, f"{prefix}_tsne_combined.pdf")
    
    # if "dpp4_bit" in save_path:
    #     continue
    # --- Skip if already exists ---
    if os.path.exists(save_path):
        print(f"⏩ {save_path} already exists. Skipping...")
        continue

    print(f"\n🚀 Processing group {prefix}")

    all_embeddings = []
    all_labels = []

    for f in group_files:
        file_path = os.path.join(tsne_dir, f)
        
        #####
        if 'ood' in file_path:
            continue
        
        # if 'train' not in file_path and 'context' not in file_path:
        #     continue
        #####
        
        data = np.load(file_path)
        
        embeddings = data['embeddings']
        labels = data['labels']

        print(f"✅ Loaded {f}: embeddings {embeddings.shape}, labels {labels.shape}")

        all_embeddings.append(embeddings)
        all_labels.append(labels)

    if len(all_embeddings) == 0 or len(all_labels) == 0:
        continue
    
    # Concatenate all
    all_embeddings = np.concatenate(all_embeddings, axis=0)
    all_labels = np.concatenate(all_labels, axis=0)

    print(f"✅ Combined embeddings shape: {all_embeddings.shape}")

    # --- Run t-SNE ---
    # if gpu_available:
    #     embeddings_gpu = cp.asarray(all_embeddings)
    #     tsne = cuTSNE(n_components=2, random_state=42)
    #     embeddings_2d_gpu = tsne.fit_transform(embeddings_gpu)
    #     embeddings_2d = cp.asnumpy(embeddings_2d_gpu)
    # else:
    tsne = cpuTSNE(n_components=2, n_jobs=8, random_state=42)
    embeddings_2d = tsne.fit(all_embeddings)

    # --- Plot ---
    import matplotlib.patches as mpatches
    import matplotlib.pyplot as plt

    # Set global font
    plt.rcParams['font.family'] = 'DejaVu Sans'
    plt.rcParams['font.size'] = 10

    # --- t-SNE Scatter Plot with Nice Legend and Slight Grid ---

    plt.figure(figsize=(8, 6))

    # Define color mapping
    color_map = {0: '#ffb347', 1: '#0000CD', -1: '#DDA0DD'}  # orange and blue
    colors = [color_map[label] for label in all_labels]

    # Set point sizes
    sizes = [40 if label == 1 else 15 for label in all_labels]

    # Scatter plot
    scatter = plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], c=colors, s=sizes, alpha=0.8)

    # Slight soft grid
    plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.3)

    # Hide axis labels but keep grid
    plt.gca().set_xticklabels([])
    plt.gca().set_yticklabels([])
    plt.xlabel("")
    plt.ylabel("")
    plt.box(False)

    # --- Add better legend ---
    import matplotlib.lines as mlines

    # Define custom legend handles (use Line2D for circles)
    orange_circle = mlines.Line2D([], [], color='#ffb347', marker='o', linestyle='None', markersize=8, label='ours')
    blue_circle = mlines.Line2D([], [], color='#0000CD', marker='o', linestyle='None', markersize=8, label='ours (w/o context)')
    red_circle = mlines.Line2D([], [], color='#DDA0DD', marker='o', linestyle='None', markersize=8, label='ours (context)')

    # Add legend inside plot (upper right)
    plt.legend(handles=[orange_circle, blue_circle, red_circle],
            loc='upper right',  # inside the plot, top right
            framealpha=0.6,
            prop={'size': 12},
            handletextpad=0.4,
            borderpad=0.5)

    # Tight layout
    plt.tight_layout()

    # Save figure
    plt.savefig(save_path, dpi=300)
    print(f"✅ Saved t-SNE scatter plot with nice legend to {save_path}")
    plt.close()
# Out:
# ⚠️ cuML not available, falling back to CPU openTSNE
#
# 🚀 Processing group dsets_dpp4_bit_100_100
#
# 🚀 Processing group dsets_dpp4_bit_100_10
#
# 🚀 Processing group dsets_dpp4_bit_100_40
#
# 🚀 Processing group dsets_dpp4_bit_100_50
#
# 🚀 Processing group dsets_dpp4_bit_100_5
# ✅ Loaded dsets_dpp4_bit_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_dpp4_bit_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_dpp4_bit_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_bit_10_100
# ✅ Loaded dsets_dpp4_bit_10_100_context_none.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded dsets_dpp4_bit_10_100_train_context.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded dsets_dpp4_bit_10_100_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (2010, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_10_100_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_bit_10_40
# ✅ Loaded dsets_dpp4_bit_10_40_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_dpp4_bit_10_40_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_dpp4_bit_10_40_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (810, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_10_40_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_bit_10_5
# ✅ Loaded dsets_dpp4_bit_10_5_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_dpp4_bit_10_5_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_dpp4_bit_10_5_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (110, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_10_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_bit_40_10
# ✅ Loaded dsets_dpp4_bit_40_10_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_dpp4_bit_40_10_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_dpp4_bit_40_10_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (840, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_40_10_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_bit_40_5
# ✅ Loaded dsets_dpp4_bit_40_5_context_none.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded dsets_dpp4_bit_40_5_train_context.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded dsets_dpp4_bit_40_5_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (440, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_40_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_bit_5_100
# ✅ Loaded dsets_dpp4_bit_5_100_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_dpp4_bit_5_100_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_dpp4_bit_5_100_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (1005, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_5_100_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_bit_5_10
# ✅ Loaded dsets_dpp4_bit_5_10_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_dpp4_bit_5_10_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Combined embeddings shape: (100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_5_10_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_bit_5_50
# ✅ Loaded dsets_dpp4_bit_5_50_context_none.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded dsets_dpp4_bit_5_50_train_context.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded dsets_dpp4_bit_5_50_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (505, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_5_50_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_count_100_100
#
# 🚀 Processing group dsets_dpp4_count_100_10
#
# 🚀 Processing group dsets_dpp4_count_100_40
#
# 🚀 Processing group dsets_dpp4_count_100_50
#
# 🚀 Processing group dsets_dpp4_count_100_5
# ✅ Loaded dsets_dpp4_count_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_dpp4_count_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_dpp4_count_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_count_10_100
# ✅ Loaded dsets_dpp4_count_10_100_context_none.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded dsets_dpp4_count_10_100_train_context.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded dsets_dpp4_count_10_100_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (2010, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_10_100_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_count_10_40
# ✅ Loaded dsets_dpp4_count_10_40_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_dpp4_count_10_40_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_dpp4_count_10_40_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (810, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_10_40_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_count_10_5
# ✅ Loaded dsets_dpp4_count_10_5_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_dpp4_count_10_5_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_dpp4_count_10_5_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (110, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_10_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_count_40_10
# ✅ Loaded dsets_dpp4_count_40_10_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_dpp4_count_40_10_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_dpp4_count_40_10_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (840, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_40_10_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_count_40_5
# ✅ Loaded dsets_dpp4_count_40_5_context_none.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded dsets_dpp4_count_40_5_train_context.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded dsets_dpp4_count_40_5_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (440, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_40_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_count_5_100
# ✅ Loaded dsets_dpp4_count_5_100_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_dpp4_count_5_100_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_dpp4_count_5_100_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (1005, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_5_100_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_count_5_10
# ✅ Loaded dsets_dpp4_count_5_10_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_dpp4_count_5_10_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Combined embeddings shape: (100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_5_10_tsne_combined.pdf
#
# 🚀 Processing group dsets_dpp4_count_5_50
# ✅ Loaded dsets_dpp4_count_5_50_context_none.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded dsets_dpp4_count_5_50_train_context.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded dsets_dpp4_count_5_50_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (505, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_5_50_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_bit_100_100
#
# 🚀 Processing group dsets_hivprot_bit_100_10
#
# 🚀 Processing group dsets_hivprot_bit_100_40
#
# 🚀 Processing group dsets_hivprot_bit_100_50
#
# 🚀 Processing group dsets_hivprot_bit_100_5
# ✅ Loaded dsets_hivprot_bit_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_hivprot_bit_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_hivprot_bit_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_bit_10_100
# ✅ Loaded dsets_hivprot_bit_10_100_context_none.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded dsets_hivprot_bit_10_100_train_context.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded dsets_hivprot_bit_10_100_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (2010, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_10_100_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_bit_10_40
# ✅ Loaded dsets_hivprot_bit_10_40_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_hivprot_bit_10_40_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_hivprot_bit_10_40_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (810, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_10_40_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_bit_10_5
# ✅ Loaded dsets_hivprot_bit_10_5_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_hivprot_bit_10_5_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_hivprot_bit_10_5_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (110, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_10_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_bit_40_10
# ✅ Loaded dsets_hivprot_bit_40_10_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_hivprot_bit_40_10_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_hivprot_bit_40_10_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (840, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_40_10_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_bit_40_5
# ✅ Loaded dsets_hivprot_bit_40_5_context_none.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded dsets_hivprot_bit_40_5_train_context.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded dsets_hivprot_bit_40_5_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (440, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_40_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_bit_5_100
# ✅ Loaded dsets_hivprot_bit_5_100_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_hivprot_bit_5_100_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_hivprot_bit_5_100_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (1005, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_5_100_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_bit_5_10
# ✅ Loaded dsets_hivprot_bit_5_10_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_hivprot_bit_5_10_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Combined embeddings shape: (100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_5_10_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_bit_5_50
# ✅ Loaded dsets_hivprot_bit_5_50_context_none.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded dsets_hivprot_bit_5_50_train_context.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded dsets_hivprot_bit_5_50_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (505, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_5_50_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_count_100_100
#
# 🚀 Processing group dsets_hivprot_count_100_10
#
# 🚀 Processing group dsets_hivprot_count_100_40
#
# 🚀 Processing group dsets_hivprot_count_100_50
#
# 🚀 Processing group dsets_hivprot_count_100_5
# ✅ Loaded dsets_hivprot_count_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_hivprot_count_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_hivprot_count_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_count_10_100
# ✅ Loaded dsets_hivprot_count_10_100_context_none.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded dsets_hivprot_count_10_100_train_context.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded dsets_hivprot_count_10_100_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (2010, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_10_100_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_count_10_40
# ✅ Loaded dsets_hivprot_count_10_40_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_hivprot_count_10_40_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_hivprot_count_10_40_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (810, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_10_40_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_count_10_5
# ✅ Loaded dsets_hivprot_count_10_5_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_hivprot_count_10_5_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_hivprot_count_10_5_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (110, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_10_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_count_40_10
# ✅ Loaded dsets_hivprot_count_40_10_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_hivprot_count_40_10_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_hivprot_count_40_10_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (840, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_40_10_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_count_40_5
# ✅ Loaded dsets_hivprot_count_40_5_context_none.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded dsets_hivprot_count_40_5_train_context.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded dsets_hivprot_count_40_5_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (440, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_40_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_count_5_100
# ✅ Loaded dsets_hivprot_count_5_100_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_hivprot_count_5_100_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_hivprot_count_5_100_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (1005, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_5_100_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_count_5_10
# ✅ Loaded dsets_hivprot_count_5_10_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_hivprot_count_5_10_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Combined embeddings shape: (100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_5_10_tsne_combined.pdf
#
# 🚀 Processing group dsets_hivprot_count_5_50
# ✅ Loaded dsets_hivprot_count_5_50_context_none.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded dsets_hivprot_count_5_50_train_context.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded dsets_hivprot_count_5_50_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (505, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_5_50_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_bit_100_100
#
# 🚀 Processing group dsets_nk1_bit_100_10
#
# 🚀 Processing group dsets_nk1_bit_100_40
#
# 🚀 Processing group dsets_nk1_bit_100_50
#
# 🚀 Processing group dsets_nk1_bit_100_5
# ✅ Loaded dsets_nk1_bit_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_nk1_bit_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_nk1_bit_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_bit_10_100
# ✅ Loaded dsets_nk1_bit_10_100_context_none.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded dsets_nk1_bit_10_100_train_context.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded dsets_nk1_bit_10_100_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (2010, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_10_100_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_bit_10_40
# ✅ Loaded dsets_nk1_bit_10_40_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_nk1_bit_10_40_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_nk1_bit_10_40_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (810, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_10_40_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_bit_10_5
# ✅ Loaded dsets_nk1_bit_10_5_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_nk1_bit_10_5_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_nk1_bit_10_5_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (110, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_10_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_bit_40_10
# ✅ Loaded dsets_nk1_bit_40_10_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_nk1_bit_40_10_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_nk1_bit_40_10_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (840, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_40_10_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_bit_40_5
# ✅ Loaded dsets_nk1_bit_40_5_context_none.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded dsets_nk1_bit_40_5_train_context.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded dsets_nk1_bit_40_5_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (440, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_40_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_bit_5_100
# ✅ Loaded dsets_nk1_bit_5_100_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_nk1_bit_5_100_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_nk1_bit_5_100_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (1005, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_5_100_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_bit_5_10
# ✅ Loaded dsets_nk1_bit_5_10_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_nk1_bit_5_10_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Combined embeddings shape: (100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_5_10_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_bit_5_50
# ✅ Loaded dsets_nk1_bit_5_50_context_none.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded dsets_nk1_bit_5_50_train_context.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded dsets_nk1_bit_5_50_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (505, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_5_50_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_count_100_100
#
# 🚀 Processing group dsets_nk1_count_100_10
#
# 🚀 Processing group dsets_nk1_count_100_40
#
# 🚀 Processing group dsets_nk1_count_100_50
#
# 🚀 Processing group dsets_nk1_count_100_5
# ✅ Loaded dsets_nk1_count_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_nk1_count_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_nk1_count_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_count_10_100
# ✅ Loaded dsets_nk1_count_10_100_context_none.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded dsets_nk1_count_10_100_train_context.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded dsets_nk1_count_10_100_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (2010, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_10_100_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_count_10_40
# ✅ Loaded dsets_nk1_count_10_40_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_nk1_count_10_40_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_nk1_count_10_40_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (810, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_10_40_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_count_10_5
# ✅ Loaded dsets_nk1_count_10_5_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_nk1_count_10_5_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_nk1_count_10_5_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (110, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_10_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_count_40_10
# ✅ Loaded dsets_nk1_count_40_10_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_nk1_count_40_10_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded dsets_nk1_count_40_10_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (840, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_40_10_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_count_40_5
# ✅ Loaded dsets_nk1_count_40_5_context_none.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded dsets_nk1_count_40_5_train_context.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded dsets_nk1_count_40_5_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (440, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_40_5_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_count_5_100
# ✅ Loaded dsets_nk1_count_5_100_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_nk1_count_5_100_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_nk1_count_5_100_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (1005, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_5_100_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_count_5_10
# ✅ Loaded dsets_nk1_count_5_10_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded dsets_nk1_count_5_10_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Combined embeddings shape: (100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_5_10_tsne_combined.pdf
#
# 🚀 Processing group dsets_nk1_count_5_50
# ✅ Loaded dsets_nk1_count_5_50_context_none.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded dsets_nk1_count_5_50_train_context.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded dsets_nk1_count_5_50_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (505, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_5_50_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_bit_100_100
#
# 🚀 Processing group strans_dpp4_bit_100_10
#
# 🚀 Processing group strans_dpp4_bit_100_40
#
# 🚀 Processing group strans_dpp4_bit_100_50
#
# 🚀 Processing group strans_dpp4_bit_100_5
# ✅ Loaded strans_dpp4_bit_100_5_context_none.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_dpp4_bit_100_5_train_context.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_dpp4_bit_100_5_train_none.npz: embeddings (100, 32), labels (100,)
# ✅ Combined embeddings shape: (1100, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_100_5_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_bit_10_100
# ✅ Loaded strans_dpp4_bit_10_100_context_none.npz: embeddings (1000, 32), labels (1000,)
# ✅ Loaded strans_dpp4_bit_10_100_train_context.npz: embeddings (1000, 32), labels (1000,)
# ✅ Loaded strans_dpp4_bit_10_100_train_none.npz: embeddings (10, 32), labels (10,)
# ✅ Combined embeddings shape: (2010, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_10_100_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_bit_10_40
# ✅ Loaded strans_dpp4_bit_10_40_context_none.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_dpp4_bit_10_40_train_context.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_dpp4_bit_10_40_train_none.npz: embeddings (10, 32), labels (10,)
# ✅ Combined embeddings shape: (810, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_10_40_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_bit_10_5
# ✅ Loaded strans_dpp4_bit_10_5_context_none.npz: embeddings (50, 32), labels (50,)
# ✅ Loaded strans_dpp4_bit_10_5_train_context.npz: embeddings (50, 32), labels (50,)
# ✅ Loaded strans_dpp4_bit_10_5_train_none.npz: embeddings (10, 32), labels (10,)
# ✅ Combined embeddings shape: (110, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_10_5_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_bit_40_10
# ✅ Loaded strans_dpp4_bit_40_10_context_none.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_dpp4_bit_40_10_train_context.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_dpp4_bit_40_10_train_none.npz: embeddings (40, 32), labels (40,)
# ✅ Combined embeddings shape: (840, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_40_10_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_bit_40_5
# ✅ Loaded strans_dpp4_bit_40_5_context_none.npz: embeddings (200, 32), labels (200,)
# ✅ Loaded strans_dpp4_bit_40_5_train_context.npz: embeddings (200, 32), labels (200,)
# ✅ Loaded strans_dpp4_bit_40_5_train_none.npz: embeddings (40, 32), labels (40,)
# ✅ Combined embeddings shape: (440, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_40_5_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_bit_5_100
# ✅ Loaded strans_dpp4_bit_5_100_context_none.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_dpp4_bit_5_100_train_context.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_dpp4_bit_5_100_train_none.npz: embeddings (5, 32), labels (5,)
# ✅ Combined embeddings shape: (1005, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_5_100_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_bit_5_10
# ✅ Loaded strans_dpp4_bit_5_10_context_none.npz: embeddings (50, 32), labels (50,)
# ✅ Loaded strans_dpp4_bit_5_10_train_context.npz: embeddings (50, 32), labels (50,)
# ✅ Combined embeddings shape: (100, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_5_10_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_bit_5_50
# ✅ Loaded strans_dpp4_bit_5_50_context_none.npz: embeddings (250, 32), labels (250,)
# ✅ Loaded strans_dpp4_bit_5_50_train_context.npz: embeddings (250, 32), labels (250,)
# ✅ Loaded strans_dpp4_bit_5_50_train_none.npz: embeddings (5, 32), labels (5,)
# ✅ Combined embeddings shape: (505, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_5_50_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_count_100_100
#
# 🚀 Processing group strans_dpp4_count_100_10
#
# 🚀 Processing group strans_dpp4_count_100_40
#
# 🚀 Processing group strans_dpp4_count_100_50
#
# 🚀 Processing group strans_dpp4_count_100_5
# ✅ Loaded strans_dpp4_count_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded strans_dpp4_count_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded strans_dpp4_count_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_count_100_5_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_count_10_100
# ✅ Loaded strans_dpp4_count_10_100_context_none.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded strans_dpp4_count_10_100_train_context.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded strans_dpp4_count_10_100_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (2010, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_count_10_100_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_count_10_40
# ✅ Loaded strans_dpp4_count_10_40_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded strans_dpp4_count_10_40_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded strans_dpp4_count_10_40_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (810, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_count_10_40_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_count_10_5
# ✅ Loaded strans_dpp4_count_10_5_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded strans_dpp4_count_10_5_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded strans_dpp4_count_10_5_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (110, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_count_10_5_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_count_40_10
# ✅ Loaded strans_dpp4_count_40_10_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded strans_dpp4_count_40_10_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded strans_dpp4_count_40_10_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (840, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_count_40_10_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_count_40_5
# ✅ Loaded strans_dpp4_count_40_5_context_none.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded strans_dpp4_count_40_5_train_context.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded strans_dpp4_count_40_5_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (440, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_count_40_5_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_count_5_100
# ✅ Loaded strans_dpp4_count_5_100_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded strans_dpp4_count_5_100_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded strans_dpp4_count_5_100_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (1005, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_count_5_100_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_count_5_10
# ✅ Loaded strans_dpp4_count_5_10_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded strans_dpp4_count_5_10_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Combined embeddings shape: (100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_count_5_10_tsne_combined.pdf
#
# 🚀 Processing group strans_dpp4_count_5_50
# ✅ Loaded strans_dpp4_count_5_50_context_none.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded strans_dpp4_count_5_50_train_context.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded strans_dpp4_count_5_50_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (505, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_count_5_50_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_bit_100_100
#
# 🚀 Processing group strans_hivprot_bit_100_10
#
# 🚀 Processing group strans_hivprot_bit_100_40
#
# 🚀 Processing group strans_hivprot_bit_100_50
#
# 🚀 Processing group strans_hivprot_bit_100_5
# ✅ Loaded strans_hivprot_bit_100_5_context_none.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_hivprot_bit_100_5_train_context.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_hivprot_bit_100_5_train_none.npz: embeddings (100, 32), labels (100,)
# ✅ Combined embeddings shape: (1100, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_bit_100_5_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_bit_10_100
# ✅ Loaded strans_hivprot_bit_10_100_context_none.npz: embeddings (1000, 32), labels (1000,)
# ✅ Loaded strans_hivprot_bit_10_100_train_context.npz: embeddings (1000, 32), labels (1000,)
# ✅ Loaded strans_hivprot_bit_10_100_train_none.npz: embeddings (10, 32), labels (10,)
# ✅ Combined embeddings shape: (2010, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_bit_10_100_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_bit_10_40
# ✅ Loaded strans_hivprot_bit_10_40_context_none.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_hivprot_bit_10_40_train_context.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_hivprot_bit_10_40_train_none.npz: embeddings (10, 32), labels (10,)
# ✅ Combined embeddings shape: (810, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_bit_10_40_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_bit_10_5
# ✅ Loaded strans_hivprot_bit_10_5_context_none.npz: embeddings (50, 32), labels (50,)
# ✅ Loaded strans_hivprot_bit_10_5_train_context.npz: embeddings (50, 32), labels (50,)
# ✅ Loaded strans_hivprot_bit_10_5_train_none.npz: embeddings (10, 32), labels (10,)
# ✅ Combined embeddings shape: (110, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_bit_10_5_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_bit_40_10
# ✅ Loaded strans_hivprot_bit_40_10_context_none.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_hivprot_bit_40_10_train_context.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_hivprot_bit_40_10_train_none.npz: embeddings (40, 32), labels (40,)
# ✅ Combined embeddings shape: (840, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_bit_40_10_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_bit_40_5
# ✅ Loaded strans_hivprot_bit_40_5_context_none.npz: embeddings (200, 32), labels (200,)
# ✅ Loaded strans_hivprot_bit_40_5_train_context.npz: embeddings (200, 32), labels (200,)
# ✅ Loaded strans_hivprot_bit_40_5_train_none.npz: embeddings (40, 32), labels (40,)
# ✅ Combined embeddings shape: (440, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_bit_40_5_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_bit_5_100
# ✅ Loaded strans_hivprot_bit_5_100_context_none.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_hivprot_bit_5_100_train_context.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_hivprot_bit_5_100_train_none.npz: embeddings (5, 32), labels (5,)
# ✅ Combined embeddings shape: (1005, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_bit_5_100_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_bit_5_10
# ✅ Loaded strans_hivprot_bit_5_10_context_none.npz: embeddings (50, 32), labels (50,)
# ✅ Loaded strans_hivprot_bit_5_10_train_context.npz: embeddings (50, 32), labels (50,)
# ✅ Combined embeddings shape: (100, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_bit_5_10_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_bit_5_50
# ✅ Loaded strans_hivprot_bit_5_50_context_none.npz: embeddings (250, 32), labels (250,)
# ✅ Loaded strans_hivprot_bit_5_50_train_context.npz: embeddings (250, 32), labels (250,)
# ✅ Loaded strans_hivprot_bit_5_50_train_none.npz: embeddings (5, 32), labels (5,)
# ✅ Combined embeddings shape: (505, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_bit_5_50_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_count_100_100
#
# 🚀 Processing group strans_hivprot_count_100_10
#
# 🚀 Processing group strans_hivprot_count_100_40
#
# 🚀 Processing group strans_hivprot_count_100_50
#
# 🚀 Processing group strans_hivprot_count_100_5
# ✅ Loaded strans_hivprot_count_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded strans_hivprot_count_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded strans_hivprot_count_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_count_100_5_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_count_10_100
# ✅ Loaded strans_hivprot_count_10_100_context_none.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded strans_hivprot_count_10_100_train_context.npz: embeddings (1000, 64), labels (1000,)
# ✅ Loaded strans_hivprot_count_10_100_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (2010, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_count_10_100_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_count_10_40
# ✅ Loaded strans_hivprot_count_10_40_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded strans_hivprot_count_10_40_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded strans_hivprot_count_10_40_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (810, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_count_10_40_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_count_10_5
# ✅ Loaded strans_hivprot_count_10_5_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded strans_hivprot_count_10_5_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded strans_hivprot_count_10_5_train_none.npz: embeddings (10, 64), labels (10,)
# ✅ Combined embeddings shape: (110, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_count_10_5_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_count_40_10
# ✅ Loaded strans_hivprot_count_40_10_context_none.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded strans_hivprot_count_40_10_train_context.npz: embeddings (400, 64), labels (400,)
# ✅ Loaded strans_hivprot_count_40_10_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (840, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_count_40_10_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_count_40_5
# ✅ Loaded strans_hivprot_count_40_5_context_none.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded strans_hivprot_count_40_5_train_context.npz: embeddings (200, 64), labels (200,)
# ✅ Loaded strans_hivprot_count_40_5_train_none.npz: embeddings (40, 64), labels (40,)
# ✅ Combined embeddings shape: (440, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_count_40_5_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_count_5_100
# ✅ Loaded strans_hivprot_count_5_100_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded strans_hivprot_count_5_100_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded strans_hivprot_count_5_100_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (1005, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_count_5_100_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_count_5_10
# ✅ Loaded strans_hivprot_count_5_10_context_none.npz: embeddings (50, 64), labels (50,)
# ✅ Loaded strans_hivprot_count_5_10_train_context.npz: embeddings (50, 64), labels (50,)
# ✅ Combined embeddings shape: (100, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_count_5_10_tsne_combined.pdf
#
# 🚀 Processing group strans_hivprot_count_5_50
# ✅ Loaded strans_hivprot_count_5_50_context_none.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded strans_hivprot_count_5_50_train_context.npz: embeddings (250, 64), labels (250,)
# ✅ Loaded strans_hivprot_count_5_50_train_none.npz: embeddings (5, 64), labels (5,)
# ✅ Combined embeddings shape: (505, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_count_5_50_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_bit_100_100
#
# 🚀 Processing group strans_nk1_bit_100_10
#
# 🚀 Processing group strans_nk1_bit_100_40
#
# 🚀 Processing group strans_nk1_bit_100_50
#
# 🚀 Processing group strans_nk1_bit_100_5
# ✅ Loaded strans_nk1_bit_100_5_context_none.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_nk1_bit_100_5_train_context.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_nk1_bit_100_5_train_none.npz: embeddings (100, 32), labels (100,)
# ✅ Combined embeddings shape: (1100, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_5_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_bit_10_100
# ✅ Loaded strans_nk1_bit_10_100_context_none.npz: embeddings (1000, 32), labels (1000,)
# ✅ Loaded strans_nk1_bit_10_100_train_context.npz: embeddings (1000, 32), labels (1000,)
# ✅ Loaded strans_nk1_bit_10_100_train_none.npz: embeddings (10, 32), labels (10,)
# ✅ Combined embeddings shape: (2010, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_10_100_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_bit_10_40
# ✅ Loaded strans_nk1_bit_10_40_context_none.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_nk1_bit_10_40_train_context.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_nk1_bit_10_40_train_none.npz: embeddings (10, 32), labels (10,)
# ✅ Combined embeddings shape: (810, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_10_40_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_bit_10_5
# ✅ Loaded strans_nk1_bit_10_5_context_none.npz: embeddings (50, 32), labels (50,)
# ✅ Loaded strans_nk1_bit_10_5_train_context.npz: embeddings (50, 32), labels (50,)
# ✅ Loaded strans_nk1_bit_10_5_train_none.npz: embeddings (10, 32), labels (10,)
# ✅ Combined embeddings shape: (110, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_10_5_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_bit_40_10
# ✅ Loaded strans_nk1_bit_40_10_context_none.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_nk1_bit_40_10_train_context.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_nk1_bit_40_10_train_none.npz: embeddings (40, 32), labels (40,)
# ✅ Combined embeddings shape: (840, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_40_10_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_bit_40_5
# ✅ Loaded strans_nk1_bit_40_5_context_none.npz: embeddings (200, 32), labels (200,)
# ✅ Loaded strans_nk1_bit_40_5_train_context.npz: embeddings (200, 32), labels (200,)
# ✅ Loaded strans_nk1_bit_40_5_train_none.npz: embeddings (40, 32), labels (40,)
# ✅ Combined embeddings shape: (440, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_40_5_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_bit_5_100
# ✅ Loaded strans_nk1_bit_5_100_context_none.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_nk1_bit_5_100_train_context.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_nk1_bit_5_100_train_none.npz: embeddings (5, 32), labels (5,)
# ✅ Combined embeddings shape: (1005, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_5_100_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_bit_5_10
# ✅ Loaded strans_nk1_bit_5_10_context_none.npz: embeddings (50, 32), labels (50,)
# ✅ Loaded strans_nk1_bit_5_10_train_context.npz: embeddings (50, 32), labels (50,)
# ✅ Combined embeddings shape: (100, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_5_10_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_bit_5_50
# ✅ Loaded strans_nk1_bit_5_50_context_none.npz: embeddings (250, 32), labels (250,)
# ✅ Loaded strans_nk1_bit_5_50_train_context.npz: embeddings (250, 32), labels (250,)
# ✅ Loaded strans_nk1_bit_5_50_train_none.npz: embeddings (5, 32), labels (5,)
# ✅ Combined embeddings shape: (505, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_5_50_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_count_100_100
#
# 🚀 Processing group strans_nk1_count_100_10
#
# 🚀 Processing group strans_nk1_count_100_40
#
# 🚀 Processing group strans_nk1_count_100_50
#
# 🚀 Processing group strans_nk1_count_100_5
# ✅ Loaded strans_nk1_count_100_5_context_none.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_nk1_count_100_5_train_context.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_nk1_count_100_5_train_none.npz: embeddings (100, 32), labels (100,)
# ✅ Combined embeddings shape: (1100, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_5_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_count_10_100
# ✅ Loaded strans_nk1_count_10_100_context_none.npz: embeddings (1000, 32), labels (1000,)
# ✅ Loaded strans_nk1_count_10_100_train_context.npz: embeddings (1000, 32), labels (1000,)
# ✅ Loaded strans_nk1_count_10_100_train_none.npz: embeddings (10, 32), labels (10,)
# ✅ Combined embeddings shape: (2010, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_10_100_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_count_10_40
# ✅ Loaded strans_nk1_count_10_40_context_none.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_nk1_count_10_40_train_context.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_nk1_count_10_40_train_none.npz: embeddings (10, 32), labels (10,)
# ✅ Combined embeddings shape: (810, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_10_40_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_count_10_5
# ✅ Loaded strans_nk1_count_10_5_context_none.npz: embeddings (50, 32), labels (50,)
# ✅ Loaded strans_nk1_count_10_5_train_context.npz: embeddings (50, 32), labels (50,)
# ✅ Loaded strans_nk1_count_10_5_train_none.npz: embeddings (10, 32), labels (10,)
# ✅ Combined embeddings shape: (110, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_10_5_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_count_40_10
# ✅ Loaded strans_nk1_count_40_10_context_none.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_nk1_count_40_10_train_context.npz: embeddings (400, 32), labels (400,)
# ✅ Loaded strans_nk1_count_40_10_train_none.npz: embeddings (40, 32), labels (40,)
# ✅ Combined embeddings shape: (840, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_40_10_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_count_40_5
# ✅ Loaded strans_nk1_count_40_5_context_none.npz: embeddings (200, 32), labels (200,)
# ✅ Loaded strans_nk1_count_40_5_train_context.npz: embeddings (200, 32), labels (200,)
# ✅ Loaded strans_nk1_count_40_5_train_none.npz: embeddings (40, 32), labels (40,)
# ✅ Combined embeddings shape: (440, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_40_5_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_count_5_100
# ✅ Loaded strans_nk1_count_5_100_context_none.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_nk1_count_5_100_train_context.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_nk1_count_5_100_train_none.npz: embeddings (5, 32), labels (5,)
# ✅ Combined embeddings shape: (1005, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_5_100_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_count_5_10
# ✅ Loaded strans_nk1_count_5_10_context_none.npz: embeddings (50, 32), labels (50,)
# ✅ Loaded strans_nk1_count_5_10_train_context.npz: embeddings (50, 32), labels (50,)
# ✅ Combined embeddings shape: (100, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_5_10_tsne_combined.pdf
#
# 🚀 Processing group strans_nk1_count_5_50
# ✅ Loaded strans_nk1_count_5_50_context_none.npz: embeddings (250, 32), labels (250,)
# ✅ Loaded strans_nk1_count_5_50_train_context.npz: embeddings (250, 32), labels (250,)
# ✅ Loaded strans_nk1_count_5_50_train_none.npz: embeddings (5, 32), labels (5,)
# ✅ Combined embeddings shape: (505, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_5_50_tsne_combined.pdf

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

# Try to use GPU TSNE (cuML), fallback to CPU TSNE (openTSNE)
# try:
#     import cupy as cp
#     from cuml.manifold import TSNE as cuTSNE
#     gpu_available = True
#     print("✅ Using GPU cuML TSNE")
# except ImportError:
from openTSNE import TSNE as cpuTSNE
gpu_available = False
print("⚠️ cuML not available, falling back to CPU openTSNE")

# Set your directory
tsne_dir = '/c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/'

# List all .npz files
files = sorted([f for f in os.listdir(tsne_dir) if f.endswith('.npz')])

# --- Group files by their starting prefix (before 3rd underscore) ---
groups = defaultdict(list)
for f in files:
    parts = f.split('_')
    
    prefix = '_'.join(parts[:5])  # e.g., dsets_dpp4_count

    if 'ood' not in f:
        groups[prefix].append(f)
    
    prefix_ = '_'.join(parts[:3])
    if prefix_ in prefix and 'ood' in f:
        groups[prefix].append(f)

# --- Process each group ---
for prefix, group_files in groups.items():
    save_path = os.path.join(tsne_dir, f"{prefix}_tsne_combined_all.pdf")
    
    # if "dpp4_bit" in save_path:
    #     continue
    # --- Skip if already exists ---
    if os.path.exists(save_path):
        print(f"⏩ {save_path} already exists. Skipping...")
        continue

    print(f"\n🚀 Processing group {prefix}")

    all_embeddings = []
    all_labels = []

    for f in group_files:
        file_path = os.path.join(tsne_dir, f)
        
        if len(group_files) != 5:
            print('group_files ', len(group_files))
            continue
        #####
        # if 'ood' in file_path:
        #     continue
        
        # if 'train' not in file_path and 'context' not in file_path:
        #     continue
        #####
        
        data = np.load(file_path)
        
        embeddings = data['embeddings']
        labels = data['labels']

        print(f"✅ Loaded {f}: embeddings {embeddings.shape}, labels {labels.shape}")

        all_embeddings.append(embeddings)
        all_labels.append(labels)

    if len(all_embeddings) == 0 or len(all_labels) == 0:
        continue
    
    # Concatenate all
    all_embeddings = np.concatenate(all_embeddings, axis=0)
    all_labels = np.concatenate(all_labels, axis=0)

    print(f"✅ Combined embeddings shape: {all_embeddings.shape}")

    # --- Run t-SNE ---
    # if gpu_available:
    #     embeddings_gpu = cp.asarray(all_embeddings)
    #     tsne = cuTSNE(n_components=2, random_state=42)
    #     embeddings_2d_gpu = tsne.fit_transform(embeddings_gpu)
    #     embeddings_2d = cp.asnumpy(embeddings_2d_gpu)
    # else:
    tsne = cpuTSNE(n_components=2, n_jobs=8, random_state=42)
    embeddings_2d = tsne.fit(all_embeddings)

    # --- Plot ---
    import matplotlib.patches as mpatches
    import matplotlib.pyplot as plt

    # Set global font
    plt.rcParams['font.family'] = 'DejaVu Sans'
    plt.rcParams['font.size'] = 10

    # --- t-SNE Scatter Plot with Nice Legend and Slight Grid ---

    plt.figure(figsize=(8, 6))

    # Define color mapping
    color_map = {0: '#ffb347', 1: '#0000CD', -1: '#DDA0DD', 3:'#48b33c', 4:'#3cadb3'}  # orange and blue
    colors = [color_map[label] for label in all_labels]

    # Set point sizes
    sizes = [40 if label == 1 else 15 for label in all_labels]

    # Scatter plot
    scatter = plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], c=colors, s=sizes, alpha=0.8)

    # Slight soft grid
    plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.3)

    # Hide axis labels but keep grid
    plt.gca().set_xticklabels([])
    plt.gca().set_yticklabels([])
    plt.xlabel("")
    plt.ylabel("")
    plt.box(False)

    # --- Add better legend ---
    import matplotlib.lines as mlines

    # Define custom legend handles (use Line2D for circles)
    orange_circle = mlines.Line2D([], [], color='#ffb347', marker='o', linestyle='None', markersize=8, label='ours')
    blue_circle = mlines.Line2D([], [], color='#0000CD', marker='o', linestyle='None', markersize=8, label='ours (w/o context)')
    red_circle = mlines.Line2D([], [], color='#DDA0DD', marker='o', linestyle='None', markersize=8, label='ours (context)')
    green_circle = mlines.Line2D([], [], color='#48b33c', marker='o', linestyle='None', markersize=8, label='OOD1')
    bluegreen_circle = mlines.Line2D([], [], color='#3cadb3', marker='o', linestyle='None', markersize=8, label='OOD2')

    # Add legend inside plot (upper right)
    plt.legend(handles=[orange_circle, blue_circle, red_circle, green_circle, bluegreen_circle],
            loc='upper right',  # inside the plot, top right
            framealpha=0.6,
            prop={'size': 12},
            handletextpad=0.4,
            borderpad=0.5)

    # Tight layout
    plt.tight_layout()

    # Save figure
    plt.savefig(save_path, dpi=300)
    print(f"✅ Saved t-SNE scatter plot with nice legend to {save_path}")
    plt.close()
# Out:
# ⚠️ cuML not available, falling back to CPU openTSNE
#
# 🚀 Processing group dsets_dpp4_bit_100_100
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_dpp4_bit_100_10
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_dpp4_bit_100_40
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_dpp4_bit_100_50
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_dpp4_bit_100_5
# ✅ Loaded dsets_dpp4_bit_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_dpp4_bit_100_5_ood1_none.npz: embeddings (100, 64), labels (100,)
# ✅ Loaded dsets_dpp4_bit_100_5_ood2_none.npz: embeddings (100, 64), labels (100,)
# ✅ Loaded dsets_dpp4_bit_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_dpp4_bit_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1300, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_bit_100_5_tsne_combined_all.pdf
#
# 🚀 Processing group dsets_dpp4_bit_10_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_dpp4_bit_10_40
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_dpp4_bit_10_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_dpp4_bit_40_10
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_dpp4_bit_40_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_dpp4_bit_5_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_dpp4_bit_5_10
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_dpp4_bit_5_50
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_dpp4_count_100_100
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_dpp4_count_100_10
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_dpp4_count_100_40
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_dpp4_count_100_50
# group_files  2
# group_files  2
# ⏩ /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_dpp4_count_100_5_tsne_combined_all.pdf already exists. Skipping...
#
# 🚀 Processing group dsets_dpp4_count_10_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_dpp4_count_10_40
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_dpp4_count_10_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_dpp4_count_40_10
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_dpp4_count_40_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_dpp4_count_5_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_dpp4_count_5_10
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_dpp4_count_5_50
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_hivprot_bit_100_100
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_hivprot_bit_100_10
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_hivprot_bit_100_40
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_hivprot_bit_100_50
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_hivprot_bit_100_5
# ✅ Loaded dsets_hivprot_bit_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_hivprot_bit_100_5_ood1_none.npz: embeddings (100, 64), labels (100,)
# ✅ Loaded dsets_hivprot_bit_100_5_ood2_none.npz: embeddings (100, 64), labels (100,)
# ✅ Loaded dsets_hivprot_bit_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_hivprot_bit_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1300, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_bit_100_5_tsne_combined_all.pdf
#
# 🚀 Processing group dsets_hivprot_bit_10_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_hivprot_bit_10_40
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_hivprot_bit_10_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_hivprot_bit_40_10
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_hivprot_bit_40_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_hivprot_bit_5_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_hivprot_bit_5_10
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_hivprot_bit_5_50
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_hivprot_count_100_100
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_hivprot_count_100_10
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_hivprot_count_100_40
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_hivprot_count_100_50
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_hivprot_count_100_5
# ✅ Loaded dsets_hivprot_count_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_hivprot_count_100_5_ood1_none.npz: embeddings (100, 64), labels (100,)
# ✅ Loaded dsets_hivprot_count_100_5_ood2_none.npz: embeddings (100, 64), labels (100,)
# ✅ Loaded dsets_hivprot_count_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_hivprot_count_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1300, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_hivprot_count_100_5_tsne_combined_all.pdf
#
# 🚀 Processing group dsets_hivprot_count_10_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_hivprot_count_10_40
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_hivprot_count_10_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_hivprot_count_40_10
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_hivprot_count_40_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_hivprot_count_5_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_hivprot_count_5_10
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_hivprot_count_5_50
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_nk1_bit_100_100
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_nk1_bit_100_10
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_nk1_bit_100_40
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_nk1_bit_100_50
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_nk1_bit_100_5
# ✅ Loaded dsets_nk1_bit_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_nk1_bit_100_5_ood1_none.npz: embeddings (100, 64), labels (100,)
# ✅ Loaded dsets_nk1_bit_100_5_ood2_none.npz: embeddings (100, 64), labels (100,)
# ✅ Loaded dsets_nk1_bit_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_nk1_bit_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1300, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_bit_100_5_tsne_combined_all.pdf
#
# 🚀 Processing group dsets_nk1_bit_10_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_nk1_bit_10_40
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_nk1_bit_10_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_nk1_bit_40_10
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_nk1_bit_40_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_nk1_bit_5_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_nk1_bit_5_10
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_nk1_bit_5_50
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_nk1_count_100_100
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_nk1_count_100_10
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_nk1_count_100_40
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_nk1_count_100_50
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_nk1_count_100_5
# ✅ Loaded dsets_nk1_count_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_nk1_count_100_5_ood1_none.npz: embeddings (100, 64), labels (100,)
# ✅ Loaded dsets_nk1_count_100_5_ood2_none.npz: embeddings (100, 64), labels (100,)
# ✅ Loaded dsets_nk1_count_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded dsets_nk1_count_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1300, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/dsets_nk1_count_100_5_tsne_combined_all.pdf
#
# 🚀 Processing group dsets_nk1_count_10_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_nk1_count_10_40
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_nk1_count_10_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_nk1_count_40_10
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_nk1_count_40_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_nk1_count_5_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group dsets_nk1_count_5_10
# group_files  2
# group_files  2
#
# 🚀 Processing group dsets_nk1_count_5_50
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_dpp4_bit_100_100
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_dpp4_bit_100_10
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_dpp4_bit_100_40
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_dpp4_bit_100_50
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_dpp4_bit_100_5
# ✅ Loaded strans_dpp4_bit_100_5_context_none.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_dpp4_bit_100_5_ood1_none.npz: embeddings (100, 32), labels (100,)
# ✅ Loaded strans_dpp4_bit_100_5_ood2_none.npz: embeddings (100, 32), labels (100,)
# ✅ Loaded strans_dpp4_bit_100_5_train_context.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_dpp4_bit_100_5_train_none.npz: embeddings (100, 32), labels (100,)
# ✅ Combined embeddings shape: (1300, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_bit_100_5_tsne_combined_all.pdf
#
# 🚀 Processing group strans_dpp4_bit_10_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_dpp4_bit_10_40
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_dpp4_bit_10_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_dpp4_bit_40_10
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_dpp4_bit_40_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_dpp4_bit_5_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_dpp4_bit_5_10
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_dpp4_bit_5_50
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_dpp4_count_100_100
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_dpp4_count_100_10
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_dpp4_count_100_40
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_dpp4_count_100_50
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_dpp4_count_100_5
# ✅ Loaded strans_dpp4_count_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded strans_dpp4_count_100_5_ood1_none.npz: embeddings (100, 64), labels (100,)
# ✅ Loaded strans_dpp4_count_100_5_ood2_none.npz: embeddings (100, 64), labels (100,)
# ✅ Loaded strans_dpp4_count_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded strans_dpp4_count_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1300, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_dpp4_count_100_5_tsne_combined_all.pdf
#
# 🚀 Processing group strans_dpp4_count_10_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_dpp4_count_10_40
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_dpp4_count_10_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_dpp4_count_40_10
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_dpp4_count_40_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_dpp4_count_5_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_dpp4_count_5_10
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_dpp4_count_5_50
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_hivprot_bit_100_100
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_hivprot_bit_100_10
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_hivprot_bit_100_40
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_hivprot_bit_100_50
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_hivprot_bit_100_5
# ✅ Loaded strans_hivprot_bit_100_5_context_none.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_hivprot_bit_100_5_ood1_none.npz: embeddings (100, 32), labels (100,)
# ✅ Loaded strans_hivprot_bit_100_5_ood2_none.npz: embeddings (100, 32), labels (100,)
# ✅ Loaded strans_hivprot_bit_100_5_train_context.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_hivprot_bit_100_5_train_none.npz: embeddings (100, 32), labels (100,)
# ✅ Combined embeddings shape: (1300, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_bit_100_5_tsne_combined_all.pdf
#
# 🚀 Processing group strans_hivprot_bit_10_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_hivprot_bit_10_40
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_hivprot_bit_10_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_hivprot_bit_40_10
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_hivprot_bit_40_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_hivprot_bit_5_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_hivprot_bit_5_10
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_hivprot_bit_5_50
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_hivprot_count_100_100
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_hivprot_count_100_10
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_hivprot_count_100_40
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_hivprot_count_100_50
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_hivprot_count_100_5
# ✅ Loaded strans_hivprot_count_100_5_context_none.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded strans_hivprot_count_100_5_ood1_none.npz: embeddings (100, 64), labels (100,)
# ✅ Loaded strans_hivprot_count_100_5_ood2_none.npz: embeddings (100, 64), labels (100,)
# ✅ Loaded strans_hivprot_count_100_5_train_context.npz: embeddings (500, 64), labels (500,)
# ✅ Loaded strans_hivprot_count_100_5_train_none.npz: embeddings (100, 64), labels (100,)
# ✅ Combined embeddings shape: (1300, 64)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_hivprot_count_100_5_tsne_combined_all.pdf
#
# 🚀 Processing group strans_hivprot_count_10_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_hivprot_count_10_40
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_hivprot_count_10_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_hivprot_count_40_10
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_hivprot_count_40_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_hivprot_count_5_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_hivprot_count_5_10
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_hivprot_count_5_50
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_nk1_bit_100_100
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_nk1_bit_100_10
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_nk1_bit_100_40
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_nk1_bit_100_50
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_nk1_bit_100_5
# ✅ Loaded strans_nk1_bit_100_5_context_none.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_nk1_bit_100_5_ood1_none.npz: embeddings (100, 32), labels (100,)
# ✅ Loaded strans_nk1_bit_100_5_ood2_none.npz: embeddings (100, 32), labels (100,)
# ✅ Loaded strans_nk1_bit_100_5_train_context.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_nk1_bit_100_5_train_none.npz: embeddings (100, 32), labels (100,)
# ✅ Combined embeddings shape: (1300, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_bit_100_5_tsne_combined_all.pdf
#
# 🚀 Processing group strans_nk1_bit_10_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_nk1_bit_10_40
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_nk1_bit_10_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_nk1_bit_40_10
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_nk1_bit_40_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_nk1_bit_5_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_nk1_bit_5_10
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_nk1_bit_5_50
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_nk1_count_100_100
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_nk1_count_100_10
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_nk1_count_100_40
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_nk1_count_100_50
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_nk1_count_100_5
# ✅ Loaded strans_nk1_count_100_5_context_none.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_nk1_count_100_5_ood1_none.npz: embeddings (100, 32), labels (100,)
# ✅ Loaded strans_nk1_count_100_5_ood2_none.npz: embeddings (100, 32), labels (100,)
# ✅ Loaded strans_nk1_count_100_5_train_context.npz: embeddings (500, 32), labels (500,)
# ✅ Loaded strans_nk1_count_100_5_train_none.npz: embeddings (100, 32), labels (100,)
# ✅ Combined embeddings shape: (1300, 32)
# ✅ Saved t-SNE scatter plot with nice legend to /c2/jinakim/Drug_Discovery_j/analysis/tsne_last_REAL2/2nd_last_ours_best_/strans_nk1_count_100_5_tsne_combined_all.pdf
#
# 🚀 Processing group strans_nk1_count_10_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_nk1_count_10_40
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_nk1_count_10_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_nk1_count_40_10
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_nk1_count_40_5
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_nk1_count_5_100
# group_files  3
# group_files  3
# group_files  3
#
# 🚀 Processing group strans_nk1_count_5_10
# group_files  2
# group_files  2
#
# 🚀 Processing group strans_nk1_count_5_50
# group_files  3
# group_files  3
# group_files  3
